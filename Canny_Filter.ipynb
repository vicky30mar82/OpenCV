# %% [markdown]
# <a href="https://colab.research.google.com/github/vicky30mar82/OpenCV/blob/main/Canny_Filter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
#Read image
image = cv2.imread('Img1.jpg')

#Conver to Grey scale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
#Plot the image
plt.imshow(gray, cmap="gray")
plt.show()

# %%
#Edge Detection
edges = cv2.Canny(gray, 50, 90)
cv2_imshow(edges)
#plt.show()
# Out:
# <PIL.Image.Image image mode=L size=2720x1720 at 0x7FC000CBF190>

# %%
#For Live Camera
cap = cv2.VideoCapture(0)

# %%
while True:
  _, frame = cap.read()
  gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
  edges = cv2.Canny(gray, 50, 100)
  cv2.imshow("edges", edges)
  cv2.imshow("gray", gray)
  if cv2.waitKey(1) == ord("q"):
    break
  
  cap.release()
  cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-55-1ec520ebf04b> in <module>()
#       1 while True:
#       2   _, frame = cap.read()
# ----> 3   gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#       4   edges = cv2.Canny(gray, 50, 100)
#       5   cv2.imshow("edges", edges)
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
